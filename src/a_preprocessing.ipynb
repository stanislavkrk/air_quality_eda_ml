# %%
from preprocessors.open_read_check import loader, drop_empty_rows
from preprocessors.working_with_data_categories import date_and_time
from preprocessors.transform_comas_to_float import comas_to_float
from preprocessors.simple_imputer import simple_imputer
from preprocessors.check_missing import check_missing
from preprocessors.save_dataset import save_dataframe

import numpy as np
import seaborn as sns

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Load data and cleaning

# %% [markdown]
# Open and check

# %%
df = loader()
df.head(5)
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH  Unnamed: 15  Unnamed: 16
# ...

# %% [markdown]
# Сheck empty rows and drop them

# %%
drop_empty_rows(df)
# Out:
# Initial shape: (9471, 17)
#      Date Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 9357  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9358  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9359  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9360  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9361  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# ...   ...  ...    ...          ...       ...      ...            ...      ...
# 9466  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9467  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9468  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9469  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9470  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
#
# ...

# %% [markdown]
# Check if the last 2 columns has values

# %%
print('Cheking if all column 15 is empty:', df['Unnamed: 15'].isna().all())
print('Cheking if all column 16 is empty:', df['Unnamed: 16'].isna().all())
# Out:
# Cheking if all column 15 is empty: True
# Cheking if all column 16 is empty: True

# %% [markdown]
# Drop empty columns

# %%
df.drop(['Unnamed: 15', 'Unnamed: 16'], axis=1, inplace=True)
df.head()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH
# 0  0,7578
# 1  0,7255
# 2  0,7502
# 3  0,7867
# ...

# %% [markdown]
# ## Transformation of some categories of data

# %% [markdown]
# Check data categories

# %%
df.dtypes
# Out:
# Date              object
# Time              object
# CO(GT)            object
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)          object
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                 object
# RH                object
# AH                object
# dtype: object

# %% [markdown]
# Working with date and time

# %%
date_and_time(df)
df.head()
# Out:
#         Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0 2004-03-10  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1 2004-03-10  19.00.00      2       1292.0     112.0      9,4          955.0
# 2 2004-03-10  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3 2004-03-10  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4 2004-03-10  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH            DateTime  Hour
# ...

# %% [markdown]
# Convert comas to dots for making 'float' from 'objects' categories

# %%
comas_to_float(df)
df.dtypes
# Out:
# Date             datetime64[ns]
# Time                     object
# CO(GT)                  float64
# PT08.S1(CO)             float64
# NMHC(GT)                float64
# C6H6(GT)                float64
# PT08.S2(NMHC)           float64
# NOx(GT)                 float64
# PT08.S3(NOx)            float64
# NO2(GT)                 float64
# PT08.S4(NO2)            float64
# PT08.S5(O3)             float64
# T                       float64
# RH                      float64
# AH                      float64
# DateTime         datetime64[ns]
# Hour                      int64
# dtype: object

# %% [markdown]
# Compare it, there are no comas

# %%
df.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0 2004-03-10  18.00.00     2.6       1360.0     150.0      11.9
# 1 2004-03-10  19.00.00     2.0       1292.0     112.0       9.4
# 2 2004-03-10  20.00.00     2.2       1402.0      88.0       9.0
# 3 2004-03-10  21.00.00     2.2       1376.0      80.0       9.2
# 4 2004-03-10  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH            DateTime  Hour
# 0  13.6  48.9  0.7578 2004-03-10 18:00:00    18
# ...

# %% [markdown]
# Check main statistics

# %%
df.describe(include='all')
# Out:
#                                  Date      Time       CO(GT)  PT08.S1(CO)  \
# count                            9357      9357  9357.000000  9357.000000
# unique                            NaN        24          NaN          NaN
# top                               NaN  18.00.00          NaN          NaN
# freq                              NaN       390          NaN          NaN
# mean    2004-09-21 04:30:05.193972480       NaN   -34.207524  1048.990061
# min               2004-03-10 00:00:00       NaN  -200.000000  -200.000000
# 25%               2004-06-16 00:00:00       NaN     0.600000   921.000000
# 50%               2004-09-21 00:00:00       NaN     1.500000  1053.000000
# 75%               2004-12-28 00:00:00       NaN     2.600000  1221.000000
# max               2005-04-04 00:00:00       NaN    11.900000  2040.000000
# std                               NaN       NaN    77.657170   329.832710
#
#            NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)      NOx(GT)  PT08.S3(NOx)  \
# ...

# %% [markdown]
# The NaN value, according to dataset description, has value -200. Let`s change this value to NaN.

# %%
df.replace(-200, np.nan, inplace=True)
df.describe()
# Out:
#                                 Date       CO(GT)  PT08.S1(CO)     NMHC(GT)  \
# count                           9357  7674.000000  8991.000000   914.000000
# mean   2004-09-21 04:30:05.193972480     2.152750  1099.833166   218.811816
# min              2004-03-10 00:00:00     0.100000   647.000000     7.000000
# 25%              2004-06-16 00:00:00     1.100000   937.000000    67.000000
# 50%              2004-09-21 00:00:00     1.800000  1063.000000   150.000000
# 75%              2004-12-28 00:00:00     2.900000  1231.000000   297.000000
# max              2005-04-04 00:00:00    11.900000  2040.000000  1189.000000
# std                              NaN     1.453252   217.080037   204.459921
#
#           C6H6(GT)  PT08.S2(NMHC)      NOx(GT)  PT08.S3(NOx)      NO2(GT)  \
# count  8991.000000    8991.000000  7718.000000   8991.000000  7715.000000
# mean     10.083105     939.153376   246.896735    835.493605   113.091251
# ...

# %% [markdown]
# Let`s drop almost empty strokes.
# After that we can see no changes in main statistics.

# %%
df.dropna(thresh=5, inplace=True)
df.describe()
# Out:
#                                 Date       CO(GT)  PT08.S1(CO)     NMHC(GT)  \
# count                           9326  7674.000000  8991.000000   914.000000
# mean   2004-09-21 09:21:06.909714560     2.152750  1099.833166   218.811816
# min              2004-03-10 00:00:00     0.100000   647.000000     7.000000
# 25%              2004-06-16 00:00:00     1.100000   937.000000    67.000000
# 50%              2004-09-22 00:00:00     1.800000  1063.000000   150.000000
# 75%              2004-12-28 00:00:00     2.900000  1231.000000   297.000000
# max              2005-04-04 00:00:00    11.900000  2040.000000  1189.000000
# std                              NaN     1.453252   217.080037   204.459921
#
#           C6H6(GT)  PT08.S2(NMHC)      NOx(GT)  PT08.S3(NOx)      NO2(GT)  \
# count  8991.000000    8991.000000  7718.000000   8991.000000  7715.000000
# mean     10.083105     939.153376   246.896735    835.493605   113.091251
# ...

# %% [markdown]
# ### Transform data with log-function and check distribution

# %% [markdown]
# The sensors in our dataset have a strong difference in values.
# It will be good idea to transform data with log-function for: normalization, symmetrization.
# To prevent errors for values <0, we need to transform this values to NaN before log-function realisation. We do it with copy of main dataset.

# %%
df_log_input = df.iloc[:, 2:15].copy()
df_log_input[df_log_input <= 0] = np.nan
dfm = np.log(df_log_input).melt(var_name='columns')

# %% [markdown]
# Let`s visualize our dataset after log-transformation.

# %%
g = sns.displot(data=dfm, x='value', col='columns', col_wrap=3, common_norm=False, kde=True, stat='density')

# %% [markdown]
# ### Let`s save current dataset with all changes as new file.
# We going to continue work with missings in second Jupiter Notebook.

# %%
save_dataframe(df, path='data/processed', filename='AirQualityUCI_stage_one.csv')
# Out:
# Dataset saved to: data/processed\AirQualityUCI_stage_one.csv
